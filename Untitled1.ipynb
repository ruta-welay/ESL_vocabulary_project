# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import re
import joblib

# %%
dd1 = pd.read_csv("words.csv")
dd2 = pd.read_csv("word_pos.csv")
dd3 = pd.read_csv("word_categories.csv")
dd4 = pd.read_csv("word_list_cefr.csv", sep=";")

# %%
dd1.head()
# Out:
#    word_id word  stem_word_id
# 0        1  the           NaN
# 1        2   of           NaN
# 2        3  and           NaN
# 3        4   to           NaN
# 4        5   in           NaN

# %%
dd2.head()
# Out:
#    word_pos_id  word_id  pos_tag_id  lemma_word_id  frequency_count  level
# 0            1   159572          12            NaN            14306    6.0
# 1            2   109633          14            NaN            66173    6.0
# 2            3    77173          12            NaN            10456    4.0
# 3            4     4266          12            NaN         23948680    3.0
# 4            5    40616          14            NaN           842163    6.0

# %%
dd3.head()
# Out:
#    word_pos_id  category_id
# 0           60            1
# 1         5578            2
# 2          141            3
# 3         1068            3
# 4         1544            4

# %%
dd4.head()
# Out:
#     headword         pos CEFR CoreInventory 1 CoreInventory 2 Threshold
# 0          a  determiner   A1             NaN             NaN       NaN
# 1       a.m.      adverb   A1             NaN             NaN       NaN
# 2       A.M.      adverb   A1             NaN             NaN       NaN
# 3    abandon        verb   B1             NaN             NaN       NaN
# 4  abandoned   adjective   B2             NaN             NaN       NaN

# %%
row_count = len(dd)
print(f"Number of rows: {row_count}")
# Out:
# Number of rows: 248184

# %%
row_count = len(dd4)
print(f"Number of rows: {row_count}")
# Out:
# Number of rows: 7988
